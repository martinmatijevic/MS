# %%
from numpy import array, random
BIG_ENOUGH = 5_000_000
random.seed(42)

def is_covered(room, sensors):
    points = random.rand(BIG_ENOUGH, 2) * room
    real, imag, radii = array(sensors).T
    inside = abs(points.view(complex) - (real+1j*imag).T) <= radii
    return inside.any(axis=1).all()

# %%
import numpy as np
(np.random.rand(5, 2) * [3, 9]).view(complex)
# Out:
# array([[1.53703376+3.10169687j],
#        [1.77083663+3.13710903j],
#        [1.42045471+2.12021635j],
#        [0.7902704 +2.87078519j],
#        [2.76625352+3.07210585j]])

# %%
prvi = np.array([2+3j])
drugi = np.array([[6, 3, 9]])
abs(prvi - drugi.T) <= np.array([5, 2, 0])
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [False, False, False]])

# %% [markdown]
# Sensors: 3n brojeva, za svaki senzor x,y,r

# %%
is_covered([200, 150], [[100, 75, 130]])
# Out:
# True

# %%
from sGithuba import TESTS
# Out:
# (0, 0) 1
# (0, 350) 1
# (1400, 0) 1
# (1400, 350) 1
# (279.342488, 247.895919) 2
# (967.519015, 47.683511) 2
# (815.325686, 226.734486) 2
# (1281.931902, 214.306042) 3
# (1176.002707, 68.913029) 2
# (1179.464554, 100.481985) 3
# (1206.26985, 91.166558) 3
# (673.7321420000001, 0) 1
# (166.267858, 0) 2
# (234.946802, 0) 2
# (227.37634, 350) 1
# (1400, 205.171426) 2
# (1191.826196, 0) 1
# (1275.9137, 350) 2
# (824.0862999999999, 350) 1
# (1400, 139.250209) 2
# (1064.285923, 350) 2
# (0, 0) 1
# (0, 250) 3
# (500, 0) 3
# (500, 250) 1
# (249.640123, 228.999617) 4
# (213.656608, 57.749225) 4
# (341.309804, 161.293607) 4
# (297.19539, 11.947936) 4
# (367.432087, 181.534788) 3
# (332.503331, 207.493052) 3
# (412.675941, 14.201111) 4
# (406.881762, 122.841967) 4
# (303.161474, 220.420877) 4
# (88.145548, 11.377616) 3
# (240.046882, 0) 3
# (269.290398, 250) 3
# (500, 196.825401) 2
# (300.51756, 0) 3
# (287.336071, 0) 3
# (314.348884, 250) 2
# (407.990506, 0) 3
# (92.00949399999999, 0) 2
# ...

# %%
TESTS
# Out:
# {'Basics': [{'input': [[200, 150], [[100, 75, 130]]], 'answer': True},
#   {'input': [[200, 150], [[50, 75, 100], [150, 75, 100]]], 'answer': True},
#   {'input': [[200, 150], [[50, 75, 100], [150, 25, 50], [150, 125, 50]]],
#    'answer': False},
#   {'input': [[200, 150],
#     [[100, 75, 100],
#      [0, 40, 60],
#      [0, 110, 60],
#      [200, 40, 60],
#      [200, 110, 60]]],
#    'answer': True},
#   {'input': [[200, 150],
#     [[100, 75, 100],
#      [0, 40, 50],
#      [0, 110, 50],
#      [200, 40, 50],
#      [200, 110, 50]]],
#    'answer': False},
#   {'input': [[200, 150], [[100, 75, 110], [105, 75, 110]]], 'answer': False},
#   {'input': [[200, 150], [[100, 75, 110], [105, 75, 20]]], 'answer': False},
#   {'input': [[3, 1], [[1, 0, 2], [2, 1, 2]]], 'answer': True},
#   {'input': [[30, 10], [[0, 10, 10], [10, 0, 10], [20, 10, 10], [30, 0, 10]]],
#    'answer': True},
#   {'input': [[30, 10], [[0, 10, 8], [10, 0, 7], [20, 10, 9], [30, 0, 10]]],
#    'answer': False}],
# ...

# %%
for vrsta in TESTS.keys():
    print(TESTS[vrsta][0])
# Out:
# {'input': [[200, 150], [[100, 75, 130]]], 'answer': True}
# {'input': [[8, 6], [[4, 3, 5]]], 'answer': True}
# {'input': [[1400, 350], [[420, 34, 256], [0, 170, 290], [910, 153, 120], [1330, 68, 154], [490, 119, 69], [1050, 272, 239], [1260, 289, 205]]], 'answer': False}

# %%
input = [[200, 150], [[100, 75, 130]]]

# %%
args = [2, 3, 5]
def f(x,y,z): return x+y*z
f(*args)
# Out:
# 17

# %%
is_covered(*input)
# Out:
# True

# %%
for vrsta_testova, testovi in TESTS.items():
    print(vrsta_testova)
    for i, test in enumerate(testovi):
        input, answer = test.values()
        print(i, is_covered(*input) == answer)
# Out:
# Basics
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# Extra
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# Randoms
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
